# %%
import cmdstanpy as csp

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
data_all = pd.read_csv("data_500.csv")

# %%
N = data_all.shape[0]

z_sigma = data_all["z_sigma"]
median_z = data_all["median_z"]

nu = 3
lambda_value = 1

# %%
data = {'N': N, 
        'z_sigma': z_sigma,
        'median_z': median_z,
        'nu': nu,
        'lambda': lambda_value,}

# %%
model = csp.CmdStanModel(stan_file = 'linear-regression.stan')
sample = model.sample(data = data, seed = 1, chains = 1,
                      iter_sampling = 1000, iter_warmup = 1000,
                      show_progress = False, show_console = False)
# Out:
# 15:54:07 - cmdstanpy - INFO - compiling stan file /Users/pushpitkaushik/STAT775_papers/775_Astrnomy/stat-775-final/linear-regression-model/linear-regression.stan to exe file /Users/pushpitkaushik/STAT775_papers/775_Astrnomy/stat-775-final/linear-regression-model/linear-regression
# 15:54:56 - cmdstanpy - INFO - compiled model executable: /Users/pushpitkaushik/STAT775_papers/775_Astrnomy/stat-775-final/linear-regression-model/linear-regression
# 15:54:56 - cmdstanpy - INFO - CmdStan start processing
# 15:54:56 - cmdstanpy - INFO - Chain [1] start processing
# 15:54:57 - cmdstanpy - INFO - Chain [1] done processing
# 15:54:57 - cmdstanpy - WARNING - Non-fatal error during sampling:
# Exception: normal_lpdf: Scale parameter is 0, but must be positive! (in 'linear-regression.stan', line 19, column 4 to column 29)
# Consider re-running with show_console=True if the above output is unclear!

# %%
alpha_list = sample.stan_variable("alpha")
beta_list = sample.stan_variable("beta")

# %%
plt.scatter(median_z, z_sigma)
plt.xlabel("Median z")
plt.ylabel("z_sigma")
# Out:
# Text(0, 0.5, 'z_sigma')

# %%
zs = np.arange(0, np.max(median_z), np.max(median_z)/1000)
segs = []
for i in range(len(alpha_list)):
    data = alpha_list[i] + beta_list[i]*zs
    segs.append(((zs[0], data[0]), (zs[-1], data[-1])))

# %%
ln_coll = matplotlib.collections.LineCollection(segs, alpha=0.1)
ax = plt.gca()
ax.add_collection(ln_coll)
ax.set_xlim(0, 3.5)    
ax.set_ylim(0, 0.8)
plt.draw()

# %%
import cmdstanpy as csp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error

# Load data
data_all = pd.read_csv("data_500.csv")

# Define hyperparameters for the model
nu = 3
lambda_value = 1

# Initialize model
model = csp.CmdStanModel(stan_file='linear-regression.stan')

# DataFrame to store MSE results
mse_results = pd.DataFrame(columns=['template_id', 'MSE'])
min_data_points = 10  # Minimum number of data points required

# Iterate over each unique template_id
for template_id in data_all['template_id'].unique():
    subset = data_all[data_all['template_id'] == template_id]
    
    # Check if sufficient data points are available
    if len(subset) < min_data_points:
        continue
    
    N = subset.shape[0]
    z_sigma = subset["z_sigma"].to_list()
    median_z = subset["median_z"].to_list()

    # Prepare data for Stan model
    data = {
        'N': N,
        'z_sigma': z_sigma,
        'median_z': median_z,
        'nu': nu,
        'lambda': lambda_value,
    }

    # Fit the model
    sample = model.sample(data=data, seed=42, chains=1, iter_sampling=1000, iter_warmup=500)

    # Extract parameter estimates
    alpha = np.mean(sample.stan_variable("alpha"))
    beta = np.mean(sample.stan_variable("beta"))

    # Calculate predictions
    predictions = alpha + beta * np.array(median_z)

    # Calculate MSE
    mse = mean_squared_error(z_sigma, predictions)
    mse_results = mse_results.append({'template_id': template_id, 'MSE': mse}, ignore_index=True)

# Filter templates with MSE < 0.05
filtered_templates = mse_results[mse_results['MSE'] < 0.05]

# Number of plots
num_plots = filtered_templates.shape[0]

# Create subplots
fig, axes = plt.subplots(nrows=int(np.ceil(num_plots / 3)), ncols=3, figsize=(15, 5 * int(np.ceil(num_plots / 3))))
axes = axes.flatten()

# Color map
colors = plt.cm.viridis(np.linspace(0, 1, num_plots))

# Plot for each template with MSE < 0.05
for idx, (index, row) in enumerate(filtered_templates.iterrows()):
    template_id = row['template_id']
    subset = data_all[data_all['template_id'] == template_id]
    
    alpha = np.mean(sample.stan_variable("alpha"))
    beta = np.mean(sample.stan_variable("beta"))
    # Linear relationship
    z_vals = np.linspace(min(subset["median_z"]), max(subset["median_z"]), 100)
    pred_vals = alpha + beta * z_vals

    axes[idx].scatter(subset["median_z"], subset["z_sigma"], label=f'Template {template_id}', color=colors[idx])
    axes[idx].plot(z_vals, pred_vals, color='red')  # Linear fit line
    axes[idx].set_title(f'Template ID: {template_id} - MSE: {row["MSE"]:.4f}')
    axes[idx].set_xlabel("Median z")
    axes[idx].set_ylabel("z_sigma")
    axes[idx].legend()

# Adjust layout and show plot
plt.tight_layout()
plt.show()
# Out:
# 16:52:42 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# 16:52:42 - cmdstanpy - INFO - CmdStan done processing.
# /var/folders/h0/6fmj7gqn7ls2xv_xdy7d4mrc0000gn/T/ipykernel_48742/1277877273.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mse_results = mse_results.append({'template_id': template_id, 'MSE': mse}, ignore_index=True)
# 16:52:42 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# 16:52:42 - cmdstanpy - INFO - CmdStan done processing.
# /var/folders/h0/6fmj7gqn7ls2xv_xdy7d4mrc0000gn/T/ipykernel_48742/1277877273.py:54: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   mse_results = mse_results.append({'template_id': template_id, 'MSE': mse}, ignore_index=True)
# 16:52:42 - cmdstanpy - INFO - CmdStan start processing
# ...

# %%
import cmdstanpy as csp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Load data
data_all = pd.read_csv("data_500.csv")

# Define hyperparameters for the model
nu = 3
lambda_value = 1

# Initialize model
model = csp.CmdStanModel(stan_file='linear-regression.stan')

# DataFrame to store results
results = pd.DataFrame()

# Minimum number of data points required
min_data_points = 10

# Iterate over each unique template_id
for template_id in data_all['template_id'].unique():
    subset = data_all[data_all['template_id'] == template_id]
    
    # Check if sufficient data points are available
    if len(subset) < min_data_points:
        continue
    
    N = subset.shape[0]
    z_sigma = subset["z_sigma"].to_list()
    median_z = subset["median_z"].to_list()

    # Prepare data for Stan model
    data = {
        'N': N,
        'z_sigma': z_sigma,
        'median_z': median_z,
        'nu': nu,
        'lambda': lambda_value,
    }

    # Fit the model
    sample = model.sample(data=data, seed=42, chains=1, iter_sampling=1000, iter_warmup=500)

    # Extract parameter estimates
    alpha = np.mean(sample.stan_variable("alpha"))
    beta = np.mean(sample.stan_variable("beta"))

    # Calculate predictions
    predictions = alpha + beta * np.array(median_z)

    # Calculate loss functions
    mse = mean_squared_error(z_sigma, predictions)
    mae = mean_absolute_error(z_sigma, predictions)
    rms_error = rmse(z_sigma, predictions)
    mape_val = mape(z_sigma, predictions)
    r_squared = r2_score(z_sigma, predictions)

    # Store results
    results = results.append({
        'template_id': template_id,
        'MSE': mse,
        'MAE': mae,
        'RMSE': rms_error,
        'MAPE': mape_val,
        'R2': r_squared
    }, ignore_index=True)

# Filter results where MSE < 0.05
filtered_results = results[results['MSE'] < 0.05]

# Define number of columns for subplots
num_cols = 3
num_rows = int(np.ceil(len(filtered_results) / num_cols))

# Create subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, num_rows * 5))
axes = axes.flatten()  # Flatten if the grid is 2D

# Plot for each template with MSE < 0.05
for idx, (index, row) in enumerate(filtered_results.iterrows()):
    template_id = row['template_id']
    subset = data_all[data_all['template_id'] == template_id]
    
    # Plot data
    axes[idx].scatter(subset["median_z"], subset["z_sigma"], label=f'Template {template_id}', color='blue')
    
    # Plot regression line
    z_vals = np.linspace(min(subset["median_z"]), max(subset["median_z"]), 100)
    pred_vals = alpha + beta * z_vals
    axes[idx].plot(z_vals, pred_vals, color='red')
    
    # Annotate plot with loss functions
    loss_text = f'MSE: {row["MSE"]:.4f}\nMAE: {row["MAE"]:.4f}\nRMSE: {row["RMSE"]:.4f}\nMAPE: {row["MAPE"]:.2f}%\nR2: {row["R2"]:.2f}'
    axes[idx].text(0.05, 0.95, loss_text, transform=axes[idx].transAxes, verticalalignment='top')

    axes[idx].set_title(f'Template ID: {template_id}')
    axes[idx].set_xlabel('Median z')
    axes[idx].set_ylabel('z_sigma')

# Adjust layout
plt.tight_layout()
plt.show()
# Out:
# 17:12:26 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# 17:12:26 - cmdstanpy - INFO - CmdStan done processing.
# /var/folders/h0/6fmj7gqn7ls2xv_xdy7d4mrc0000gn/T/ipykernel_48742/1038424919.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# 17:12:26 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# 17:12:26 - cmdstanpy - INFO - CmdStan done processing.
# /var/folders/h0/6fmj7gqn7ls2xv_xdy7d4mrc0000gn/T/ipykernel_48742/1038424919.py:68: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results.append({
# 17:12:26 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# 17:12:26 - cmdstanpy - INFO - CmdStan done processing.
# ...

# %%
import cmdstanpy as csp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Load data
data_mags = pd.read_csv("data_mags_50000.csv")

# Compile Stan model
model = csp.CmdStanModel(stan_file="more_linear.stan")

# Plotting results
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(15, 25))  # Adjust size as needed
axes = axes.flatten()
plot_index = 0

# Analyze and plot for each unique template_id
for template_id in data_mags['template_id'].unique():
    subset = data_mags[data_mags['template_id'] == template_id]
    
    if len(subset) < 10:
        continue  # Skip if not enough data points
    
    # Prepare data for Stan model
    data = {
        'N': len(subset),
        'm20_i': subset['m20_i'].values,
        'mag_sersic_i': subset['mag_sersic_i'].values
    }

    # Fit the model
    fit = model.sample(data=data, seed=123, chains=2, iter_sampling=1000, iter_warmup=500)

    # Extract parameter estimates
    alpha = fit.stan_variable('alpha').mean()
    beta = fit.stan_variable('beta').mean()

    # Calculate predictions
    m20_vals = np.linspace(subset['m20_i'].min(), subset['m20_i'].max(), 100)
    predictions = alpha + beta * m20_vals

    # Calculate loss functions
    predicted = alpha + beta * subset['m20_i']
    mse_val = mean_squared_error(subset['mag_sersic_i'], predicted)
    mae_val = mean_absolute_error(subset['mag_sersic_i'], predicted)
    rmse_val = rmse(subset['mag_sersic_i'], predicted)
    mape_val = mape(subset['mag_sersic_i'], predicted)
    r2_val = r2_score(subset['mag_sersic_i'], predicted)

    # Plot
    ax = axes[plot_index]
    ax.scatter(subset['m20_i'], subset['mag_sersic_i'], color='blue', label='Data')
    ax.plot(m20_vals, predictions, color='red', label='Linear Fit')
    ax.text(0.5, 0.1, f'MSE: {mse_val:.4f}\nMAE: {mae_val:.4f}\nRMSE: {rmse_val:.4f}\nMAPE: {mape_val:.2f}%\nR2: {r2_val:.2f}', 
            transform=ax.transAxes, ha='center', fontsize=10, bbox=dict(facecolor='white', alpha=0.5))
    ax.set_title(f'Template ID: {template_id}')
    ax.set_xlabel('m20_i')
    ax.set_ylabel('mag_sersic_i')

    plot_index += 1

plt.tight_layout()
plt.show()
# Out:
# 20:00:27 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# 20:00:37 - cmdstanpy - INFO - CmdStan done processing.
# 20:00:37 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# 20:00:39 - cmdstanpy - INFO - CmdStan done processing.
# 20:00:39 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# 20:00:41 - cmdstanpy - INFO - CmdStan done processing.
# 20:00:41 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# 20:00:44 - cmdstanpy - INFO - CmdStan done processing.
# 20:00:44 - cmdstanpy - INFO - CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# 20:00:46 - cmdstanpy - INFO - CmdStan done processing.
# 20:00:46 - cmdstanpy - INFO - CmdStan start processing
# ...
